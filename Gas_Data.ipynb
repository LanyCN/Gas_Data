# %% [markdown]
# <a href="https://colab.research.google.com/github/LanyCN/Gas_Data/blob/main/Gas_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import io
from google.colab import files

# %% [markdown]
# Este dataset contém os registros dos preços médios semanais dos combustíveis do Brasil entre os anos de 2004 e 2019.
# Cada linha consiste em um registro de preço registrado para um tipo de combustível em uma dada localidade do Brasil.
# Alguns das principais colunas do dataset são: 'ESTADO', 'PRODUTO', 'NÚMERO DE POSTOS PESQUISADOS', 'PREÇO MÉDIO REVENDA'.
#
# Chamando um arquivo cvs do computador para o notebook

# %%
file_uploaded = files.upload()
# Out:
#      <input type="file" id="files-ff549a76-a549-4ab4-9394-e1a450bef9c5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ff549a76-a549-4ab4-9394-e1a450bef9c5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv( io.BytesIO( file_uploaded['GasPricesinBrazil_2004-2019.csv']))

# %%
data = pd.read_csv("GasPricesinBrazil_2004-2019.csv", sep = ';')

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
data.head(10)
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6           6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7           7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8           8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9           9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# ...

# %%
#Primeira verificação de valores
#Aparententemente não há valores nulos, uma vez que o número de registros do dataframe e os números de valores non-null é 106823
#Remover a coluna Unnamed, que parece ser os índices da tabela, que foram salvos como uma coluna.
#Algumas colunas possui tipo de dado object (strings), quando deveria ser float.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  object
#  2   DATA FINAL                     106823 non-null  object
#  3   REGIÃO                         106823 non-null  object
#  4   ESTADO                         106823 non-null  object
#  5   PRODUTO                        106823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  object
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           106823 non-null  float64
# ...

# %%
type (data)
# Out:
# pandas.core.frame.DataFrame

# %%
#O primeiro número representa o número de linhas
#O segundo número representa o número de colunas
data.shape
# Out:
# (106823, 21)

# %%
#imprimindo uma string formatada (f)
print(f'O DataFrame possui {data.shape[0]} linhas/observações/registros e {data.shape[1]} colunas/atribuitos/variaveis')
# Out:
# O DataFrame possui 106823 linhas/observações/registros e 21 colunas/atribuitos/variaveis

# %%
#selecionando uma coluna inteira (Series)
data['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
#outra forma de selecionar uma coluna inteira (Series)
#esta forma só funciona para colunas sem espaço, acentos, ou caracteres
data.ESTADO
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
#Series é uma lista de valores que vai representar algum eixo do DataFrame, pode ser coluna ou uma linha
type(data['ESTADO'])
# Out:
# pandas.core.series.Series

# %%
#selecionando a observacao indexada no indice 1 do dataframe
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# ...

# %%
#puxar uma coluna, considerando todas as linhas
#esta forma só funciona para colunas sem espaço, acentos, ou caracteres
#mesmo resultado de chamar o comando data.ESTADO
data.loc[:, 'ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
#para colunas que possuem rótulos com caracteres invalidos, apenas a seleção via string é valida.
data['DATA INICIAL']
# Out:
# 0         2004-05-09
# 1         2004-05-09
# 2         2004-05-09
# 3         2004-05-09
# 4         2004-05-09
#              ...
# 106818    2019-06-23
# 106819    2019-06-23
# 106820    2019-06-23
# 106821    2019-06-23
# 106822    2019-06-23
# Name: DATA INICIAL, Length: 106823, dtype: object

# %%
#Selecionando multiplas colunas
data[['PRODUTO', 'ESTADO', 'REGIÃO']]
# Out:
#                  PRODUTO               ESTADO        REGIÃO
# 0       ETANOL HIDRATADO     DISTRITO FEDERAL  CENTRO OESTE
# 1       ETANOL HIDRATADO                GOIAS  CENTRO OESTE
# 2       ETANOL HIDRATADO          MATO GROSSO  CENTRO OESTE
# 3       ETANOL HIDRATADO   MATO GROSSO DO SUL  CENTRO OESTE
# 4       ETANOL HIDRATADO              ALAGOAS      NORDESTE
# ...                  ...                  ...           ...
# 106818               GNV  RIO GRANDE DO NORTE      NORDESTE
# 106819               GNV    RIO GRANDE DO SUL           SUL
# 106820               GNV       SANTA CATARINA           SUL
# 106821               GNV            SAO PAULO       SUDESTE
# 106822               GNV              SERGIPE      NORDESTE
#
# [106823 rows x 3 columns]

# %%
#Removendo um Atributo (Coluna) do Data Frame
#O atributo 'Unnamed: 0' parece ser um ruído em nosso dataset
#O comando utilizado foi --> del data['Unamed:0']

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
#Filtragem - esse comando mostra todos os estados cujo precos dos combustiveis foram medidos
#mostra valores unicos do atributo(coluna) ESTADO
data['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
#utilizando uma seleçao condicional (comparações diretas)
#Faz uma comparacao, elemento a elemento da series, retornando uma series de booeans
data['ESTADO'] == 'SAO PAULO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821     True
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
#salvado essa series de booleans em uma variavel
selecao = data['ESTADO'] == 'SAO PAULO'
selecao.shape
# Out:
# (106823,)

# %%
#esse comando vai retornar todos os valores que retornarm True
data[selecao]
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 23              23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO
# 50              50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO
# 77              77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO
# 104            104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO
# 131            131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO
# ...            ...          ...         ...      ...        ...
# 106724      106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 106751      106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 106778      106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 106805      106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 106821      106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 23      ETANOL HIDRATADO                          4047              R$/l
# ...

# %%
#query = pergunta, coloca-se entre aspas simples
#SAO PAULO foi colocado entre aspas duplas porque é uma string dentro de outra string
data.query('ESTADO == "SAO PAULO"')
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 23              23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO
# 50              50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO
# 77              77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO
# 104            104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO
# 131            131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO
# ...            ...          ...         ...      ...        ...
# 106724      106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 106751      106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 106778      106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 106805      106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 106821      106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 23      ETANOL HIDRATADO                          4047              R$/l
# ...

# %%
#salvando o DataFrame filtrado dentro de uma nova variável, para simplificar o código para futuras análises
postos_sp = data.query('ESTADO == "SAO PAULO"')
postos_sp
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 23              23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO
# 50              50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO
# 77              77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO
# 104            104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO
# 131            131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO
# ...            ...          ...         ...      ...        ...
# 106724      106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 106751      106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 106778      106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 106805      106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 106821      106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 23      ETANOL HIDRATADO                          4047              R$/l
# ...

# %%
postos_sp.shape
# Out:
# (4263, 21)

# %%
#resetando os indices, fazendo com que os indices comecem de 0
#o comando a ser usado é: posto_sp.reset_index()
#esse comando vai gerar uma nova coluna iniciando de 0, e vai manter a coluna com os indies orginais
#para remover a coluna com a numeracao de indice original, o comando é:
postos_sp.reset_index(drop=True, inplace=True)
postos_sp
#Outra forma de escrever, e comumente usada seria:
#postos_sp = data.query('ESTADO == "SAO PAULO"'), reset_index(drop=True)
# Out:
#       Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 0             23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO
# 1             50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO
# 2             77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO
# 3            104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO
# 4            131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO
# ...          ...          ...         ...      ...        ...
# 4258      106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4259      106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4260      106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4261      106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4262      106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0     ETANOL HIDRATADO                          4047              R$/l
# 1     ETANOL HIDRATADO                          4066              R$/l
# ...

# %%
#estudo comparativo
#Selecionando registros de postos do Rio de Janeiro com Preços acima de 2 reais
data['ESTADO'] == 'RIO DE JANEIRO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
#removendo dados com valores nulos
#aparentemente não existem valores nulos, porém algumas incosistências foram notadas, como a unidade de medida ser um objecto no lugar de float, assim como o preço médio de distribuição
#observei que embora não esteja com valor vazio, algumas celulas com valores errados podem passar por não nulos
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  object
#  2   DATA FINAL                     106823 non-null  object
#  3   REGIÃO                         106823 non-null  object
#  4   ESTADO                         106823 non-null  object
#  5   PRODUTO                        106823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  object
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           106823 non-null  float64
# ...

# %%
#criando uma cópia para analisar esses valores com tipos errados
data_pre = data.copy()

# %%
data_pre['DATA INICIAL'] = pd.to_datetime(data_pre['DATA INICIAL'])
data_pre['DATA FINAL'] = pd.to_datetime(data_pre['DATA FINAL'])

# %%
#verificado quais colunas deveriam ter valores numéricos
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  datetime64[ns]
#  2   DATA FINAL                     106823 non-null  datetime64[ns]
#  3   REGIÃO                         106823 non-null  object
#  4   ESTADO                         106823 non-null  object
#  5   PRODUTO                        106823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  object
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
# ...

# %%
#convertendo valores para numeric, usando a funcão pd.numeric
#de acordo com a documentação do Pandas, das três opções de saída para essa conversão (ignore, raise or coerce), e que por default é raise, ficarei com a opção coerce para definir como nulos os valores que não correspondem a números


for atributo in ['MARGEM MÉDIA REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO', 'DESVIO PADRÃO DISTRIBUIÇÃO', 'PREÇO MÍNIMO DISTRIBUIÇÃO', 'PREÇO MÁXIMO DISTRIBUIÇÃO', 'COEF DE VARIAÇÃO DISTRIBUIÇÃO']:
    print(atributo)
# Out:
# MARGEM MÉDIA REVENDA
# PREÇO MÉDIO DISTRIBUIÇÃO
# DESVIO PADRÃO DISTRIBUIÇÃO
# PREÇO MÍNIMO DISTRIBUIÇÃO
# PREÇO MÁXIMO DISTRIBUIÇÃO
# COEF DE VARIAÇÃO DISTRIBUIÇÃO

# %%
data_pre[atributo] = pd.to_numeric(data_pre[atributo], errors='coerce')
